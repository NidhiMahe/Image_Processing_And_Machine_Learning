# %%
pip install deepface
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting deepface
#   Downloading deepface-0.0.92-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: requests>=2.27.1 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from deepface) (2.31.0)
# Requirement already satisfied: numpy>=1.14.0 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from deepface) (1.26.4)
# Requirement already satisfied: pandas>=0.23.4 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from deepface) (2.2.1)
# Collecting gdown>=3.10.1 (from deepface)
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: tqdm>=4.30.0 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from deepface) (4.66.4)
# Requirement already satisfied: Pillow>=5.2.0 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from deepface) (10.1.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from deepface) (4.10.0.84)
# Requirement already satisfied: tensorflow>=1.9.0 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from deepface) (2.17.0)
# Requirement already satisfied: keras>=2.2.0 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from deepface) (3.4.1)
# Requirement already satisfied: Flask>=1.1.2 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from deepface) (3.0.0)
# Collecting mtcnn>=0.1.0 (from deepface)
#   Downloading mtcnn-0.1.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting retina-face>=0.0.1 (from deepface)
#   Downloading retina_face-0.0.17-py3-none-any.whl.metadata (10 kB)
# Collecting fire>=0.4.0 (from deepface)
#   Downloading fire-0.6.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 679.9 kB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting gunicorn>=20.1.0 (from deepface)
#   Downloading gunicorn-22.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: six in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from fire>=0.4.0->deepface) (1.15.0)
# Requirement already satisfied: termcolor in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from fire>=0.4.0->deepface) (2.4.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from Flask>=1.1.2->deepface) (3.0.1)
# Requirement already satisfied: Jinja2>=3.1.2 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from Flask>=1.1.2->deepface) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from Flask>=1.1.2->deepface) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from Flask>=1.1.2->deepface) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from Flask>=1.1.2->deepface) (1.7.0)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from Flask>=1.1.2->deepface) (6.8.0)
# Requirement already satisfied: beautifulsoup4 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from gdown>=3.10.1->deepface) (4.12.2)
# Requirement already satisfied: filelock in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from gdown>=3.10.1->deepface) (3.15.4)
# Requirement already satisfied: packaging in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from gunicorn>=20.1.0->deepface) (23.2)
# Requirement already satisfied: absl-py in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from keras>=2.2.0->deepface) (2.1.0)
# Requirement already satisfied: rich in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from keras>=2.2.0->deepface) (13.7.1)
# Requirement already satisfied: namex in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from keras>=2.2.0->deepface) (0.0.8)
# Requirement already satisfied: h5py in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from keras>=2.2.0->deepface) (3.11.0)
# Requirement already satisfied: optree in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from keras>=2.2.0->deepface) (0.12.1)
# Requirement already satisfied: ml-dtypes in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from keras>=2.2.0->deepface) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from pandas>=0.23.4->deepface) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from pandas>=0.23.4->deepface) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from requests>=2.27.1->deepface) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from requests>=2.27.1->deepface) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from requests>=2.27.1->deepface) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from requests>=2.27.1->deepface) (2023.11.17)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from tensorflow>=1.9.0->deepface) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from tensorflow>=1.9.0->deepface) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from tensorflow>=1.9.0->deepface) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from tensorflow>=1.9.0->deepface) (4.25.3)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow>=1.9.0->deepface) (58.0.4)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from tensorflow>=1.9.0->deepface) (4.8.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from tensorflow>=1.9.0->deepface) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from tensorflow>=1.9.0->deepface) (1.65.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from tensorflow>=1.9.0->deepface) (2.17.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from tensorflow>=1.9.0->deepface) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface) (0.37.0)
# Requirement already satisfied: zipp>=0.5 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=3.6.0->Flask>=1.1.2->deepface) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from Jinja2>=3.1.2->Flask>=1.1.2->deepface) (2.1.3)
# Requirement already satisfied: markdown>=2.6.8 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.18,>=2.17->tensorflow>=1.9.0->deepface) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.18,>=2.17->tensorflow>=1.9.0->deepface) (0.7.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.5)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown>=3.10.1->deepface)
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from rich->keras>=2.2.0->deepface) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from rich->keras>=2.2.0->deepface) (2.17.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/nidhi/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich->keras>=2.2.0->deepface) (0.1.2)
# Downloading deepface-0.0.92-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.5/105.5 kB 877.2 kB/s eta 0:00:000:00:01
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Downloading gunicorn-22.0.0-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.4/84.4 kB 509.2 kB/s eta 0:00:00a 0:00:01
# Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 844.0 kB/s eta 0:00:0000:0100:01
# Downloading retina_face-0.0.17-py3-none-any.whl (25 kB)
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117047 sha256=32f1b66ac7b1b1f7cdae918c1d47dd5344df9f1d71fc44246a4318b4db6408bf
#   Stored in directory: /Users/nidhi/Library/Caches/pip/wheels/ec/ce/ba/9d5764d2266c500c18776c7d8f1e3c023075994cbc6dea47db
# Successfully built fire
# Installing collected packages: PySocks, gunicorn, fire, gdown, mtcnn, retina-face, deepface
# Successfully installed PySocks-1.7.1 deepface-0.0.92 fire-0.6.0 gdown-5.2.0 gunicorn-22.0.0 mtcnn-0.1.1 retina-face-0.0.17
# Note: you may need to restart the kernel to use updated packages.

# %%
from deepface import DeepFace
import matplotlib.pyplot as plt
import cv2

# Paths to the images you want to compare
image1_path = '/users/Nidhi/Desktop/Amitabhb2.jpg'
image2_path = '/users/Nidhi/Desktop/Amitabhb.jpg'

# Verify if the two images are of the same person
result = DeepFace.verify(image1_path, image2_path)

# Print the result
if result["verified"]:
    print("The faces are of the same person.")
else:
    print("The faces are of different people.")

# Load images using OpenCV
image1 = cv2.imread(image1_path)
image2 = cv2.imread(image2_path)

# Convert BGR to RGB for displaying with matplotlib
image1_rgb = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
image2_rgb = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)

# Display images
plt.subplot(1, 2, 1)
plt.imshow(image1_rgb)
plt.title('First Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image2_rgb)
plt.title('Second Image')
plt.axis('off')

plt.show()
# Out:
# The faces are of the same person.
