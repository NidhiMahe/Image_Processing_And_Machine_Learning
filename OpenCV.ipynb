# %%
''' 
OpenCV (Open Source Computer Vision Library) is a popular library used for computer vision and image processing tasks. 
It provides tools and functions for a wide range of operations, from basic image manipulation to advanced computer vision techniques.

Key Features of OpenCV
Image Processing:
Filtering: Apply filters such as blurring, sharpening, and edge detection.
Geometric Transformations: Resize, rotate, and warp images.
Color Space Conversions: Convert images between different color spaces (e.g., BGR to RGB, grayscale).

Computer Vision:
Feature Detection: Detect and describe features like corners, edges, and blobs.
Object Detection: Identify and classify objects within images using pre-trained models.
Face Recognition: Detect and recognize faces using various algorithms.

Machine Learning:
Train and Use Models: Integrate with machine learning frameworks for tasks such as classification and regression.
Pre-trained Models: Use pre-trained models for object detection, image classification, etc.

Video Processing:
Capture Video: Read and write video files, capture video from cameras.
Video Analysis: Process video frames, detect motion, and analyze video streams.

Integration:
Python, C++, Java, and more: Available bindings for multiple programming languages.
Compatible with other libraries: Works well with libraries like NumPy and TensorFlow.'''
# Out:
# ' \nOpenCV (Open Source Computer Vision Library) is a popular library used for computer vision and image processing tasks. \nIt provides tools and functions for a wide range of operations, from basic image manipulation to advanced computer vision techniques.\n\nKey Features of OpenCV\nImage Processing:\nFiltering: Apply filters such as blurring, sharpening, and edge detection.\nGeometric Transformations: Resize, rotate, and warp images.\nColor Space Conversions: Convert images between different color spaces (e.g., BGR to RGB, grayscale).\n\nComputer Vision:\nFeature Detection: Detect and describe features like corners, edges, and blobs.\nObject Detection: Identify and classify objects within images using pre-trained models.\nFace Recognition: Detect and recognize faces using various algorithms.\n\nMachine Learning:\nTrain and Use Models: Integrate with machine learning frameworks for tasks such as classification and regression.\nPre-trained Models: Use pre-trained models for object d
# ...

# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python-headless
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# Read an image
image = cv2.imread('Dog.jpg')

# Display the image in a window
cv2.imshow('Image Window', image)

# Wait for a key press and close the window
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 2024-07-28 14:12:09.281 Python[62557:4038366] WARNING: Secure coding is automatically enabled for restorable state! However, not on all supported macOS versions of this application. Opt-in to secure coding explicitly by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState:.

# %%
from skimage import io

# %%
io.imshow(image)

# %%
import cv2

# Read an image
image = cv2.imread('Dog.jpg')

# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Display the grayscale image
cv2.imshow('Grayscale Image', gray_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
io.imshow(gray_image)

# %%
import cv2

# Read an image
image = cv2.imread('Dog.jpg')

# Apply Gaussian blur
blurred_image = cv2.GaussianBlur(image, (15, 15), 0)

# Display the blurred image
cv2.imshow('Blurred Image', blurred_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
io.imshow(gray_image)

# %%
import cv2

# Read an image
image = cv2.imread('Dog.jpg')

# Convert to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply Canny edge detection
edges = cv2.Canny(gray_image, 100, 200)

# Display the edges
cv2.imshow('Edges', edges)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
io.imshow(edges)
