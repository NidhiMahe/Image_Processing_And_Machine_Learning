# %%
''' Scale-Invariant Feature Transform (SIFT) algorithm is a powerful feature detection and description tool, 
it is not the most suitable choice for face recognition tasks.

For accurate and efficient face recognition, using specialized algorithms and libraries like Haar Cascades, LBPH, FaceNet, VGG-Face, Dlib,
or OpenCV's DNN module is recommended over SIFT.
These tools are designed to handle the complexities of face recognition more effectively.

Summary of SIFT Algorithm Steps

1)Space Construction:
Gaussian Blurring: Apply Gaussian blurring to remove noise and less important points.
Image Resizing: Resize the image and repeat blurring to create different scales.

2)Difference between Gaussians:
Image Subtraction: Compute differences between blurred images to enhance scale invariance.

3)Important Points:
Identify Key Points: Detect local maxima and minima in the difference images.
Subpixel Accuracy: Use Taylor expansion to refine key point positions.
Hessian Matrix: Filter key points to include only corners, which are considered the most stable.

4)Unimportant Key Points:
Thresholding: Remove key points with low intensity values below a defined threshold.

5)Orientation of Key Points:
Gradient Direction: Determine the dominant orientation by analyzing gradients around each key point.

6)Feature Extraction: Ensure key points are unique and robust by comparing features with other images.'''
# Out:
# " Scale-Invariant Feature Transform (SIFT) algorithm is a powerful feature detection and description tool, \nit is not the most suitable choice for face recognition tasks\n\nFor accurate and efficient face recognition, using specialized algorithms and libraries like Haar Cascades, LBPH, FaceNet, VGG-Face, Dlib,\nor OpenCV's DNN module is recommended over SIFT.\nThese tools are designed to handle the complexities of face recognition more effectively.\n\nSummary of SIFT Algorithm Steps\n\n1)Space Construction:\nGaussian Blurring: Apply Gaussian blurring to remove noise and less important points.\nImage Resizing: Resize the image and repeat blurring to create different scales.\n\n2)Difference between Gaussians:\nImage Subtraction: Compute differences between blurred images to enhance scale invariance.\n\n3)Important Points:\nIdentify Key Points: Detect local maxima and minima in the difference images.\nSubpixel Accuracy: Use Taylor expansion to refine key point positions.\nHessian Matri
# ...

# %%
import cv2

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
def extract_sift_features(img):
  sift_initialize = cv2.xfeatures2d.SIFT_create()
  key_points, descriptors = sift_initialize
  detectAndCompute(img, None)
  return key_points, descriptors

# %%
def showing_sift_features(img1, img2, key_points):
  return plt.imshow(cv2.drawKeypoints(img1, key_points,img2.copy()))

# %%
import cv2
import numpy as np

# Load the images
img1 = cv2.imread('/users/Nidhi/Desktop/Nidhipics/Taj1.jpeg', cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread('/users/Nidhi/Desktop/Nidhipics/Taj2.jpg', cv2.IMREAD_GRAYSCALE)

# Initialize the SIFT detector
sift = cv2.SIFT_create()

# Detect keypoints and compute descriptors for both images
keypoints1, descriptors1 = sift.detectAndCompute(img1, None)
keypoints2, descriptors2 = sift.detectAndCompute(img2, None)

# Use FLANN-based matcher to match features
index_params = dict(algorithm=1, trees=5)
search_params = dict(checks=50)
flann = cv2.FlannBasedMatcher(index_params, search_params)
matches = flann.knnMatch(descriptors1, descriptors2, k=2)

# Apply Lowe's ratio test to filter good matches
good_matches = []
for m, n in matches:
    if m.distance < 0.7 * n.distance:
        good_matches.append(m)

# Draw matches
img_matches = cv2.drawMatches(img1, keypoints1, img2, keypoints2, good_matches, None, flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)

# Display the matches
cv2.imshow('Feature Matches', img_matches)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 2024-07-28 14:43:47.538 Python[62809:4056494] WARNING: Secure coding is automatically enabled for restorable state! However, not on all supported macOS versions of this application. Opt-in to secure coding explicitly by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState:.

# %%
import cv2
import numpy as np

# Load the images
img1 = cv2.imread('/users/Nidhi/Desktop/Nidhipics/Taj1.jpeg', cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread('/users/Nidhi/Desktop/Nidhipics/Taj2.jpg', cv2.IMREAD_GRAYSCALE)

# Initialize the SIFT detector
sift = cv2.SIFT_create()

# Detect keypoints and compute descriptors for both images
keypoints1, descriptors1 = sift.detectAndCompute(img1, None)
keypoints2, descriptors2 = sift.detectAndCompute(img2, None)

# Use FLANN-based matcher to match features
index_params = dict(algorithm=1, trees=5)
search_params = dict(checks=50)
flann = cv2.FlannBasedMatcher(index_params, search_params)
matches = flann.knnMatch(descriptors1, descriptors2, k=2)

# Apply Lowe's ratio test to filter good matches
good_matches = []
for m, n in matches:
    if m.distance < 0.7 * n.distance:
        good_matches.append(m)

# Define a threshold for determining if images are similar
MIN_MATCH_COUNT = 10  # Adjust this threshold based on your needs

if len(good_matches) > MIN_MATCH_COUNT:
    print(f"The two images are likely the same. Number of good matches: {len(good_matches)}")
else:
    print(f"The two images are likely different. Number of good matches: {len(good_matches)}")

# Draw matches
img_matches = cv2.drawMatches(img1, keypoints1, img2, keypoints2, good_matches, None, flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)

# Display the matches
cv2.imshow('Feature Matches', img_matches)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# The two images are likely the same. Number of good matches: 94

# %%
from skimage import io

# %%
io.imshow(img_matches)

# %%
import cv2
import numpy as np

# Load the images
img1 = cv2.imread('/users/Nidhi/Desktop/Amitabhb1.jpg', cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread('/users/Nidhi/Desktop/Amitabhb2.jpg', cv2.IMREAD_GRAYSCALE)

# Initialize the SIFT detector
sift = cv2.SIFT_create()

# Detect keypoints and compute descriptors for both images
keypoints1, descriptors1 = sift.detectAndCompute(img1, None)
keypoints2, descriptors2 = sift.detectAndCompute(img2, None)

# Use FLANN-based matcher to match features
index_params = dict(algorithm=1, trees=5)
search_params = dict(checks=50)
flann = cv2.FlannBasedMatcher(index_params, search_params)
matches = flann.knnMatch(descriptors1, descriptors2, k=2)

# Apply Lowe's ratio test to filter good matches
good_matches = []
for m, n in matches:
    if m.distance < 0.7 * n.distance:
        good_matches.append(m)

# Define a threshold for determining if images are similar
MIN_MATCH_COUNT = 10  # Adjust this threshold based on your needs

if len(good_matches) > MIN_MATCH_COUNT:
    print(f"The two images are likely the same. Number of good matches: {len(good_matches)}")
else:
    print(f"The two images are likely different. Number of good matches: {len(good_matches)}")

# Draw matches
img_matches = cv2.drawMatches(img1, keypoints1, img2, keypoints2, good_matches, None, flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)

# Display the matches
cv2.imshow('Feature Matches', img_matches)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# The two images are likely different. Number of good matches: 7

# %%
io.imshow(img_matches)

# %%
'''SIFT is not suitable choice for face recognition tasks'''
