# %%
'''
Scikit-image is a Python library used for image processing. It is built on top of NumPy, SciPy, and Matplotlib, and 
it provides a collection of algorithms for image processing tasks. Here's a detailed look at scikit-image:
Overview
Name: Scikit-image
Primary Purpose: Image processing in Python
Based On: NumPy, SciPy, Matplotlib

Key Features
Image I/O:
Functions to read and write images in various formats.
Supports multiple image formats (e.g., PNG, JPEG, TIFF).

Transformations:
Geometric transformations (e.g., rotation, scaling, warping).
Intensity transformations (e.g., histogram equalization, contrast stretching).

Filtering:
Linear and non-linear filters.
Edge detection filters (e.g., Sobel, Canny).
Smoothing filters (e.g., Gaussian, median).

Segmentation:
Methods to partition images into meaningful regions.
Techniques include watershed, thresholding, and region-based segmentation.

Feature Detection:
Algorithms to detect and describe key features in images.
Includes corner detection, blob detection, and texture analysis.

Morphology:
Operations to analyze and modify image shapes.
Dilation, erosion, opening, closing, etc.

Object Measurement:
Tools to measure properties of labeled image regions.
Calculate area, perimeter, shape, and more.

Use Cases
Medical Imaging: Enhancing and analyzing medical images (e.g., MRI, CT scans).
Computer Vision: Preprocessing images for computer vision tasks.
Remote Sensing: Analyzing satellite or aerial images.
Scientific Research: Processing images for various scientific applications.
Libraries and Tools
Scikit-image works well with other scientific libraries in the Python ecosystem, such as:

NumPy: For array operations.
SciPy: For advanced mathematical and statistical functions.
Matplotlib: For plotting and visualization.
OpenCV: Can be used alongside for more advanced computer vision tasks.

'''
# Out:
# "\nScikit-image is a Python library used for image processing. It is built on top of NumPy, SciPy, and Matplotlib, and \nit provides a collection of algorithms for image processing tasks. Here's a detailed look at scikit-image:\nOverview\nName: Scikit-image\nPrimary Purpose: Image processing in Python\nBased On: NumPy, SciPy, Matplotlib\n\nKey Features\nImage I/O:\nFunctions to read and write images in various formats.\nSupports multiple image formats (e.g., PNG, JPEG, TIFF).\n\nTransformations:\nGeometric transformations (e.g., rotation, scaling, warping).\nIntensity transformations (e.g., histogram equalization, contrast stretching).\n\nFiltering:\nLinear and non-linear filters.\nEdge detection filters (e.g., Sobel, Canny).\nSmoothing filters (e.g., Gaussian, median).\n\nSegmentation:\nMethods to partition images into meaningful regions.\nTechniques include watershed, thresholding, and region-based segmentation.\n\nFeature Detection:\nAlgorithms to detect and describe key features 
# ...

# %%
pip install scikit-image
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from skimage import data, io, filters

# Load an example image
image = data.coins()

# Apply a Sobel filter
edges = filters.sobel(image)

# Display the original and filtered images
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(8, 4),
                       sharex=True, sharey=True)

ax[0].imshow(image, cmap=plt.cm.gray)
ax[0].set_title('Original Image')

ax[1].imshow(edges, cmap=plt.cm.gray)
ax[1].set_title('Sobel Filter')

for a in ax:
    a.axis('off')

plt.tight_layout()
plt.show()

# %%
from skimage import io
img = io.imread('/users/Nidhi/Desktop/Amitabhb1.jpg')
io.imshow(img)

# %%
img.shape
# Out:
# (439, 402, 3)

# %%
import pandas as pd

# %%
df = pd.DataFrame(img.flatten())

# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
filepath = '/Users/Nidhi/Desktop/pixel_values1.xlsx'

# %%
df.to_excel(filepath, index=False)

# %%
from skimage import color

# %%
#Convert to HSV
img_hsv = color.rgb2hsv(img)

# %%
io.imshow(img_hsv)

# %%
img_rgb = color.hsv2rgb(img_hsv)

# %%
io.imshow(img_rgb)

# %%
img_xyz = color.rgb2xyz(img)

# %%
io.imshow(img_xyz)
# Out:
# /Users/nidhi/Library/Python/3.9/lib/python/site-packages/skimage/io/_plugins/matplotlib_plugin.py:158: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_lab = color.rgb2lab(img)

# %%
io.imshow(img_lab)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_yuv = color.rgb2yuv(img)

# %%
io.imshow(img_yuv)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_yiq = color.rgb2yiq(img)

# %%
io.imshow(img_yiq)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
