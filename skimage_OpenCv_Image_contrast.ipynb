# %%
'''OpenCV uses the BGR (Blue, Green, Red) color format by default, while most other libraries, including scikit-image, use the RGB 
(Red, Green, Blue) format. As a result, when you read and display an image with OpenCV, it may appear with incorrect colors if you do 
not convert it to the RGB format.'''

# %%
import cv2

# %%
import numpy as np

# %%
from skimage import io

# %%
image = cv2.imread("/users/Nidhi/Desktop/Amitabh.jpg")

# %%
io.imshow(image)

# %%
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
io.imshow(img_rgb)

# %%
cv2.imshow('Image (rgb)', img_rgb)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 2024-07-28 14:35:29.011 Python[62784:4054769] WARNING: Secure coding is automatically enabled for restorable state! However, not on all supported macOS versions of this application. Opt-in to secure coding explicitly by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState:.

# %%
from skimage import io

# %%
img = io.imread("/users/Nidhi/Desktop/Amitabh.jpg")

# %%
io.imshow(img)

# %%
new_image = np.zeros(img.shape, img.dtype)

# %%
contrast = 1.0

# %%
bright = 2

# %%
for y in range(img.shape[0]):
 for x in range(img.shape[1]):
  for c in range(img.shape[2]):
    new_image[y,x,c] = np.clip(contrast*img[y,x,c] +bright, 0, 255)

# %%
io.imshow(new_image)

# %%
from skimage import exposure

# %%
gamma_corrected1 = exposure.adjust_gamma(img_rgb, 5)

# %%
io.imshow(gamma_corrected1)
